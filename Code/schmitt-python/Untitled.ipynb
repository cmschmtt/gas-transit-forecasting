# %%
import pandas as pd

# %%
pd.read_excel('../../Data/raw/PET_PRI_GND_DCUS_NUS_W.xls', sheet_name=1, header=2)
# Out:
#            Date  \
# 0    1990-08-20
# 1    1990-08-27
# 2    1990-09-03
# 3    1990-09-10
# 4    1990-09-17
# ...         ...
# 1711 2023-06-05
# 1712 2023-06-12
# 1713 2023-06-19
# 1714 2023-06-26
# 1715 2023-07-03
#
#       Weekly U.S. All Grades All Formulations Retail Gasoline Prices  (Dollars per Gallon)  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 1711                                              3.655
# 1712                                              3.707
# 1713                                              3.690
# 1714                                              3.685
# 1715                                              3.643
#
# ...
